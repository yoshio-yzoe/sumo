# %%
import pandas as pd
data = "../data/"
df = pd.read_csv(data+"1996/05/幕内/14.csv", index_col=0)
df
# Out:
#    higashi_hoshi higashi_banduke higashi_shikona  higashi_id kimarite  \
# 0            win            東大関1             若乃花           3     寄り切り
# 1            win            東横綱1             貴乃花           2     寄り切り
# 2           lose            西関脇1              魁皇           7     寄り切り
# 3           lose            東関脇2              琴錦          12     上手投げ
# 4           lose             東前4             北勝鬨          30    突き落とし
# 5            win            東関脇1             武双山           6     寄り切り
# 6           lose             東前2            安芸乃島           9     上手投げ
# 7           lose             東前1             三杉里          49     寄り切り
# 8           lose            東前14              小錦        1287     下手投げ
# 9            win             東前3              寺尾          33    突き落とし
# 10          lose            西前12            栃乃和歌          23     掬い投げ
# 11          lose             東前5             朝乃翔          36    引き落とし
# ...

# %%
import pandas as pd
data = "../rikishi_data/"
df = pd.read_csv(data+"1.csv", index_col=0)
df
# Out:
#     year  month banduke   shohai yusho  kaisu  index       1       2       3  \
# 0   1988      3      前相     0勝0敗   NaN    NaN      0     NaN     NaN     NaN
# 1   1988      5    東口19     6勝1敗   NaN    NaN      0     win  yasumi  yasumi
# 2   1988      7    東二97     5勝2敗   NaN    NaN      1     win  yasumi  yasumi
# 3   1988      9    東二52     5勝2敗   NaN    NaN      2  yasumi     win  yasumi
# 4   1988     11    西二15     6勝1敗   NaN    NaN      3     win  yasumi     win
# ..   ...    ...     ...      ...   ...    ...    ...     ...     ...     ...
# 73  2000      5    東横綱1    13勝2敗   準優勝   12.0     72     win     win    lose
# 74  2000      7    東横綱1    13勝2敗    優勝   10.0     73     win     win     win
# 75  2000      9    東横綱1    13勝2敗   準優勝   13.0     74    lose     win     win
# 76  2000     11    西横綱1    14勝1敗    優勝   11.0     75     win     win    lose
# 77  2001      1    東横綱1  0勝0敗15休   NaN    NaN     76  yasumi  yasumi  yasumi
#
# ...
